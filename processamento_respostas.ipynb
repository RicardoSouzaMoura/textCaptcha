# %%
import pandas as pd
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
import pandas as pd

# %%
# %cd /gdrive/My Drive/Colab Notebooks/inteligencia coletiva/trabalho final
# Out:
# /gdrive/My Drive/Colab Notebooks/inteligencia coletiva/trabalho final

# %%
df = pd.read_csv("respostas_pesquisa.csv", header=None)

# %%
df.iloc[1][1]
# Out:
# 'aaaaaaaa amei tanto essas polaroids, nem sei expressar o quanto eu to apaixonada de vdd✨💖🎈🎉🎊 espero que outras pessoas consigam ganhar também, @chimekarlla gosto muito de fazenda  , mas morro de medo de galinha kkkkkkk, @behin_d_curtain Para mim, é precisamente o contrário  Vem a chuva e vem a boa disposição'

# %%
df
# Out:
#                         0  ...                                                  6
# 0    Carimbo de data/hora  ...           Marque as sentenças com sentido positivo
# 1     30/06/2020 21:30:36  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 2     30/06/2020 21:35:53  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 3     30/06/2020 21:36:18  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 4     30/06/2020 21:39:21  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# ..                    ...  ...                                                ...
# 321   06/07/2020 16:42:05  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 322   06/07/2020 23:06:40  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 323   07/07/2020 09:01:36  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# 324   07/07/2020 09:59:15  ...  @anadantassa_ Feliz dia das crianças :), eu co...
# ...
